# %% [markdown]
# <a href="https://colab.research.google.com/github/manutd-1878/Data-Science-Bootcamp/blob/main/01_wprowadzenie/03_funkcje_statystyczne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Funkcje statystyczne**

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
price = np.array([[12.40, 12.80, 11.90, 12.60, 1000],
                  [12.50, 13.00, 11.70, 12.20, 2000],
                  [12.20, 13.40, 12.20, 13.20, 1500]])
print(price)
# Out:
# [[  12.4   12.8   11.9   12.6 1000. ]
#  [  12.5   13.    11.7   12.2 2000. ]
#  [  12.2   13.4   12.2   13.2 1500. ]]

# %% [markdown]
# sum()

# %%
price.sum()
# Out:
# np.float64(4650.1)

# %%
price.sum(axis=0) # sumujemy po kolumnach
# Out:
# array([  37.1,   39.2,   35.8,   38. , 4500. ])

# %%
price.sum(axis=1) # sumujemy po wierszach
# Out:
# array([1049.7, 2049.4, 1551. ])

# %%
np.sum(price, axis=0)
# Out:
# array([  37.1,   39.2,   35.8,   38. , 4500. ])

# %%
np.sum(price, axis=1)
# Out:
# array([1049.7, 2049.4, 1551. ])

# %% [markdown]
# min()

# %%
np.min(price)
# Out:
# np.float64(11.7)

# %%
np.min(price, axis=0)
# Out:
# array([  12.2,   12.8,   11.7,   12.2, 1000. ])

# %%
np.min(price, axis=1)
# Out:
# array([11.9, 11.7, 12.2])

# %% [markdown]
# max()

# %%
np.max(price, axis=0)
# Out:
# array([  12.5,   13.4,   12.2,   13.2, 2000. ])

# %% [markdown]
# median()

# %%
np.median(price)
# Out:
# np.float64(12.6)

# %% [markdown]
# mean()

# %%
np.mean(price, axis=0)
# Out:
# array([  12.36666667,   13.06666667,   11.93333333,   12.66666667,
#        1500.        ])

# %% [markdown]
# std()

# %%
np.std(price, axis=0)
# Out:
# array([1.24721913e-01, 2.49443826e-01, 2.05480467e-01, 4.10960934e-01,
#        4.08248290e+02])

# %% [markdown]
# var()

# %%
np.var(price, axis=0)
# Out:
# array([1.55555556e-02, 6.22222222e-02, 4.22222222e-02, 1.68888889e-01,
#        1.66666667e+05])
